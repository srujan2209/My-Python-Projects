# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.txt',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas

# %% [markdown]
# # This topic on How to read and upload the files in pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)

# %%
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",separator=";")
df5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5b863abeb159> in <module>
# ----> 1 df5=pandas.read_csv("supermarkets-semi-colons.txt",separator=";")
#       2 df5
#
# TypeError: parser_f() got an unexpected keyword argument 'separator'

# %% [markdown]
# # By Using pandas.read_csv? It specifies all the functionalities of read_csv types and how to use them

# %%
pandas.read_csv?

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6=pandas.read_csv("data.txt")
df6
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %% [markdown]
# In The above the data doesn't have a header, In that Case we Need to specify Like these below:
# Setting Header Rows in Pandas

# %%
df6=pandas.read_csv("data.txt",header = None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %% [markdown]
# # Setting Column Names

# %%
df6.columns = ["ID","Address","City","ZIP","Country","Name","Employees"]
df6
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# # Setting Index Column
# (default index in pandas starts from zero, Suppose if we want to create our own index,
# Below are the steps)
# 1. Set the index
# 2. assign the set_index in different variable
#
# or
# 1. we can modify the data permentatly by setting index and placing inplace=True
# df.set_index("ID",inplace=True)

# %%
df6.set_index("ID")
df6
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.set_index("ID")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=df6.set_index("ID")
df7
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.set_index("Address",inplace=True)

# %%
df7
# Out:
#                           City               ZIP Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.set_index( "Name", inplace=True, drop=False)
df7
# Out:
#                       City               ZIP Country         Name  Employees
# Name
#  Madeira     San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %% [markdown]
# # Indexing and Slicing
# Here, if we need to Extract the data,from Large data sets. we use of some of these methods.
# 1. Label based Indexing   ##we use lock(loc for indexing..
# 2. Position based Indexing

# %%
df7.loc["Super River":"Ben's Shop","Country":"Employees"]
# Out:
#             Country         Name  Employees
# Name
# Super River     USA  Super River         25
# Ben's Shop      USA   Ben's Shop         10

# %%
df7.loc["Sanchez","ZIP"]
# Out:
# 'California'

# %%
df7.loc[:,"ZIP"]
# Out:
# Name
#  Madeira               CA 94114
# Bready Shop            CA 94119
# Super River    California 94114
# Ben's Shop             CA 94114
# Sanchez              California
# Richvalley             CA 94114
# Name: ZIP, dtype: object

# %%
list(df7.loc[:,"ZIP"])
# Out:
# ['CA 94114',
#  'CA 94119',
#  'California 94114',
#  'CA 94114',
#  'California',
#  'CA 94114']

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.set_index("ID",inplace=True)

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %% [markdown]
# Position Based Indexing

# %%
df5.iloc[1:4,1:4]
# Out:
#              City             State Country
# ID
# 2   San Francisco          CA 94119     USA
# 3   San Francisco  California 94114     USA
# 4   San Francisco          CA 94114     USA

# %%
df5.iloc[3,1:4]
# Out:
# City       San Francisco
# State           CA 94114
# Country              USA
# Name: 4, dtype: object

# %% [markdown]
# # DeLeting Columns and rows
# Rows starts from zero(indexing), Columns starts from 1(Columns)

# %%
df6
# Out:
#                           City               ZIP Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df6.drop("City",1)
# Out:
#                               ZIP Country         Name  Employees
# Address
# 3666 21st St             CA 94114     USA      Madeira          8
# 735 Dolores St           CA 94119     USA  Bready Shop         15
# 332 Hill St      California 94114     USA  Super River         25
# 3995 23rd St             CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St        California     USA      Sanchez         12
# 551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df6 = df6.drop("332 Hill St",0)

# %%
df6
# Out:
#                           City         ZIP Country         Name  Employees
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
df6.drop(df6.index[1:3],0) ##0????
# Out:
#                           City         ZIP Country        Name  Employees
# Address
# 3666 21st St     San Francisco    CA 94114     USA     Madeira          8
# 1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20

# %%
df6
# Out:
#                           City         ZIP Country         Name  Employees
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
df6.columns
# Out:
# Index(['City', 'ZIP', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df6.drop(df6.columns[0:3],1)
# Out:
#                         Name  Employees
# Address
# 3666 21st St         Madeira          8
# 735 Dolores St   Bready Shop         15
# 3995 23rd St      Ben's Shop         10
# 1056 Sanchez St      Sanchez         12
# 551 Alvarado St   Richvalley         20

# %% [markdown]
# # Updating and adding New Columns

# %%
df6
# Out:
#                           City         ZIP Country         Name  Employees
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
len(df6.index)
# Out:
# 5

# %%
df6["Continent"]=df6.shape[0]*["North America"] ## We Can print df6["Continent"]=["North America","North America","North America","North America","North America"]

# %%
df6
# Out:
#                           City         ZIP Country         Name  Employees  \
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20
#
#                      Continent
# Address
# 3666 21st St     North America
# 735 Dolores St   North America
# 3995 23rd St     North America
# 1056 Sanchez St  North America
# 551 Alvarado St  North America

# %%
df6.shape
# Out:
# (5, 6)

# %%
df6.shape[0]   ### Multiply by North America, Here we get 5 rows of North America
# Out:
# 5

# %%
df6
# Out:
#                           City         ZIP Country         Name  Employees  \
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20
#
#                      Continent
# Address
# 3666 21st St     North America
# 735 Dolores St   North America
# 3995 23rd St     North America
# 1056 Sanchez St  North America
# 551 Alvarado St  North America

# %%
##Modifying Continent Column (Updating Continent)
df6["Continent"]=df6["Country"]+","+"North America"

# %%
df6
# Out:
#                           City         ZIP Country         Name  Employees  \
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20
#
#                          Continent
# Address
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America
# 551 Alvarado St  USA,North America

# %%
## Adding the New row
df6_t=df6.T   ###Transporting origibal data set by rows to columns

# %%
df6_t
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# City           San Francisco      San Francisco      San Francisco
# ZIP                 CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# Address      1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco
# ZIP               California           CA 94114
# Country                  USA                USA
# Name                 Sanchez         Richvalley
# Employees                 12                 20
# Continent  USA,North America  USA,North America

# %%
df6_t["My Address"]=["My City","My ZIP","My Country","My Name","My Employees","My Continent"]

# %%
df6=df6_t.T

# %%
df6
# Out:
#                           City         ZIP     Country         Name  \
# Address
# 3666 21st St     San Francisco    CA 94114         USA      Madeira
# 735 Dolores St   San Francisco    CA 94119         USA  Bready Shop
# 3995 23rd St     San Francisco    CA 94114         USA   Ben's Shop
# 1056 Sanchez St  San Francisco  California         USA      Sanchez
# 551 Alvarado St  San Francisco    CA 94114         USA   Richvalley
# My Address             My City      My ZIP  My Country      My Name
#
#                     Employees          Continent
# Address
# 3666 21st St                8  USA,North America
# 735 Dolores St             15  USA,North America
# 3995 23rd St               10  USA,North America
# 1056 Sanchez St            12  USA,North America
# 551 Alvarado St            20  USA,North America
# My Address       My Employees       My Continent
